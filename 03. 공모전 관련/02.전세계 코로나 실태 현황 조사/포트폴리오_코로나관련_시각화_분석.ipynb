# %% [markdown]
# 최근까지 전 세계적으로 문제시 되고 있는 코로나에 대해 분석해보았습니다.
# 데이터는 제가 주로 이용하는 KAGGLE에서 가져왔으며,
# ##데이터 수집 -> 데이터 구조 파악 -> 데이터 정리 -> 데이터 시각화 -> 결론도출##
# 순으로 분석 후 결론까지 도출하는 내용을 담았습니다. 감사합니다.

# %% [markdown]
# ##1.데이터 수집
#  출처:'https://www.kaggle.com/imdevskp/corona-virus-report?select=covid_19_clean_complete.csv'

# %% [markdown]
# ###라이브러리 import

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import folium

# %% [markdown]
# ###csv 파일 업로드

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ab1fd3a3-9885-4c5d-82be-3ec2e970756f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ab1fd3a3-9885-4c5d-82be-3ec2e970756f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving covid_19_clean_complete.csv to covid_19_clean_complete.csv

# %% [markdown]
# ## 2. 데이터 구조 파악하기

# %% [markdown]
# ###데이터 pandas로 불러오기

# %%
coronaDF = pd.read_csv("covid_19_clean_complete.csv")

# %% [markdown]
# ###데이터 확인하기

# %%
coronaDF
# Out:
#       Province/State         Country/Region  ...  Active             WHO Region
# 0                NaN            Afghanistan  ...       0  Eastern Mediterranean
# 1                NaN                Albania  ...       0                 Europe
# 2                NaN                Algeria  ...       0                 Africa
# 3                NaN                Andorra  ...       0                 Europe
# 4                NaN                 Angola  ...       0                 Africa
# ...              ...                    ...  ...     ...                    ...
# 49063            NaN  Sao Tome and Principe  ...     117                 Africa
# 49064            NaN                  Yemen  ...     375  Eastern Mediterranean
# 49065            NaN                Comoros  ...      19                 Africa
# 49066            NaN             Tajikistan  ...    1147                 Europe
# 49067            NaN                Lesotho  ...     365                 Africa
#
# [49068 rows x 10 columns]

# %% [markdown]
# ###결측 값 확인

# %%
coronaDF.isnull().sum()
# Out:
# Province/State    34404
# Country/Region        0
# Lat                   0
# Long                  0
# Date                  0
# Confirmed             0
# Deaths                0
# Recovered             0
# Active                0
# WHO Region            0
# dtype: int64

# %% [markdown]
# ### 데이터 타입 조회

# %%
coronaDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49068 entries, 0 to 49067
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Province/State  14664 non-null  object
#  1   Country/Region  49068 non-null  object
#  2   Lat             49068 non-null  float64
#  3   Long            49068 non-null  float64
#  4   Date            49068 non-null  object
#  5   Confirmed       49068 non-null  int64
#  6   Deaths          49068 non-null  int64
#  7   Recovered       49068 non-null  int64
#  8   Active          49068 non-null  int64
#  9   WHO Region      49068 non-null  object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 3.7+ MB

# %% [markdown]
# ### Date 정보 수정 (Object => datetime)

# %%
coronaDF['Date'] = pd.to_datetime(coronaDF['Date'])
coronaDF
# Out:
#       Province/State         Country/Region  ...  Active             WHO Region
# 0                NaN            Afghanistan  ...       0  Eastern Mediterranean
# 1                NaN                Albania  ...       0                 Europe
# 2                NaN                Algeria  ...       0                 Africa
# 3                NaN                Andorra  ...       0                 Europe
# 4                NaN                 Angola  ...       0                 Africa
# ...              ...                    ...  ...     ...                    ...
# 49063            NaN  Sao Tome and Principe  ...     117                 Africa
# 49064            NaN                  Yemen  ...     375  Eastern Mediterranean
# 49065            NaN                Comoros  ...      19                 Africa
# 49066            NaN             Tajikistan  ...    1147                 Europe
# 49067            NaN                Lesotho  ...     365                 Africa
#
# [49068 rows x 10 columns]

# %% [markdown]
# # 코로나 바이러스 데이터 분석 - 국가별 최신 확진자, 사망자, 회복자 데이터 분석

# %% [markdown]
# ### 최신 데이터만 남기기

# %%
latestDF = coronaDF[coronaDF['Date'] == max(coronaDF['Date'])]
latestDF
# Out:
#       Province/State         Country/Region  ...  Active             WHO Region
# 48807            NaN            Afghanistan  ...    9796  Eastern Mediterranean
# 48808            NaN                Albania  ...    1991                 Europe
# 48809            NaN                Algeria  ...    7973                 Africa
# 48810            NaN                Andorra  ...      52                 Europe
# 48811            NaN                 Angola  ...     667                 Africa
# ...              ...                    ...  ...     ...                    ...
# 49063            NaN  Sao Tome and Principe  ...     117                 Africa
# 49064            NaN                  Yemen  ...     375  Eastern Mediterranean
# 49065            NaN                Comoros  ...      19                 Africa
# 49066            NaN             Tajikistan  ...    1147                 Europe
# 49067            NaN                Lesotho  ...     365                 Africa
#
# [261 rows x 10 columns]

# %% [markdown]
# ### 국가별 합계 구하기

# %%
latest_country_sum = latestDF.groupby('Country/Region')['Confirmed', 'Deaths', 'Recovered'].sum().reset_index()
latest_country_sum
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#          Country/Region  Confirmed  Deaths  Recovered
# 0           Afghanistan      36263    1269      25198
# 1               Albania       4880     144       2745
# 2               Algeria      27973    1163      18837
# 3               Andorra        907      52        803
# 4                Angola        950      41        242
# ..                  ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752
# 183      Western Sahara         10       1          8
# 184               Yemen       1691     483        833
# 185              Zambia       4552     140       2815
# 186            Zimbabwe       2704      36        542
#
# [187 rows x 4 columns]

# %% [markdown]
# ### 확진자 높은 국가순으로 정렬하기

# %%
latest_country_sum = latest_country_sum.sort_values(by='Confirmed', ascending=False).reset_index(drop=True)
latest_country_sum
# Out:
#             Country/Region  Confirmed  Deaths  Recovered
# 0                       US    4290259  148011    1325804
# 1                   Brazil    2442375   87618    1846641
# 2                    India    1480073   33408     951166
# 3                   Russia     816680   13334     602249
# 4             South Africa     452529    7067     274925
# ..                     ...        ...     ...        ...
# 182               Dominica         18       0         18
# 183  Saint Kitts and Nevis         17       0         15
# 184              Greenland         14       0         13
# 185               Holy See         12       0         12
# 186         Western Sahara         10       1          8
#
# [187 rows x 4 columns]

# %% [markdown]
# ### 데이터 전체 조회하기

# %%
latest_country_sum.style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
# #T_fb99af66_98e2_11eb_92d6_0242ac1c0002row0_col1,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row0_col2,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row1_col3{
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row0_col3{
#             background-color:  #d42121;
#             color:  #f1f1f1;
#         }#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row1_col1{
#             background-color:  #f4503a;
#             color:  #000000;
#         }#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row1_col2{
#             background-color:  #f24734;
#             color:  #000000;
#         }#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row2_col1{
#             background-color:  #fc9c7d;
#             color:  #000000;
#         }#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row2_col2{
#             background-color:  #fcc3ab;
#             color:  #000000;
#         }#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row2_col3{
#             background-color:  #fa6547;
#             color:  #000000;
#         }#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row3_col1{
#             background-color:  #fdcdb9;
#             color:  #000000;
#         }#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row3_col2,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row5_col1,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row6_col1{
#             background-color:  #fee6da;
#             color:  #000000;
#         }#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row3_col3{
#             background-color:  #fca285;
#             color:  #000000;
#         }#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row4_col1,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row9_col2,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row14_col3{
#             background-color:  #fee3d7;
#             color:  #000000;
#         }#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row4_col2,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row18_col1{
#             background-color:  #ffede5;
#             color:  #000000;
#         }#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row4_col3{
#             background-color:  #fed9c9;
#             color:  #000000;
#         }#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row5_col2{
#             background-color:  #fcab8f;
#             color:  #000000;
#         }#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row5_col3{
#             background-color:  #fdd4c2;
#             color:  #000000;
#         }#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row6_col2{
#             background-color:  #fee1d3;
#             color:  #000000;
#         }#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row6_col3{
#             background-color:  #fedaca;
#             color:  #000000;
#         }#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row7_col1,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row11_col3{
#             background-color:  #fee8dd;
#             color:  #000000;
#         }#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row7_col2,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row13_col1,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row13_col2,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row18_col2,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row20_col2{
#             background-color:  #ffebe2;
#             color:  #000000;
#         }#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row7_col3{
#             background-color:  #fdd2bf;
#             color:  #000000;
#         }#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row8_col1,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row13_col3{
#             background-color:  #fee9df;
#             color:  #000000;
#         }#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row8_col2{
#             background-color:  #fca78b;
#             color:  #000000;
#         }#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row8_col3,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row20_col3,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row22_col2,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row29_col3,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row30_col2,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row32_col2,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row35_col2,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row37_col2,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row39_col2,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row40_col3,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row41_col2,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row47_col3,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row48_col2,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row52_col2,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row55_col2,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row58_col2,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row58_col3,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row60_col2,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row61_col2,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row63_col2,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row64_col2,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row65_col2,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row66_col1,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row66_col2,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row67_col1,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row67_col2,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row67_col3,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row68_col1,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row68_col2,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row69_col1,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row69_col2,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row70_col1,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row70_col2,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row71_col1,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row71_col2,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row72_col1,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row72_col2,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row72_col3,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row73_col1,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row73_col2,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row74_col1,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row75_col1,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row75_col3,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row76_col1,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row76_col2,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row76_col3,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row77_col1,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row77_col2,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row77_col3,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row78_col1,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row78_col2,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row78_col3,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row79_col1,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row79_col2,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row79_col3,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row80_col1,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row80_col2,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row80_col3,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row81_col1,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row81_col2,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row81_col3,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row82_col1,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row82_col2,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row83_col1,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row83_col2,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row84_col1,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row84_col2,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row84_col3,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row85_col1,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row85_col2,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row85_col3,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row86_col1,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row86_col2,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row86_col3,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row87_col1,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row87_col2,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row87_col3,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row88_col1,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row88_col2,#T_fb99af66_98e2_11eb_92d6_0242ac1c0002row ...

# %% [markdown]
# # 코로나 바이러스 데이터 분석 - 시간에 따른 확진자, 사망자, 회복자 시각화

# %% [markdown]
# ###날짜별 확진자, 사망자, 회복자 합계 구하기

# %%
date_status = coronaDF.groupby('Date')['Confirmed', 'Deaths', 'Recovered'].sum()
date_status = date_status.sort_index()
date_status
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#             Confirmed  Deaths  Recovered
# Date
# 2020-01-22        555      17         28
# 2020-01-23        654      18         30
# 2020-01-24        941      26         36
# 2020-01-25       1434      42         39
# 2020-01-26       2118      56         52
# ...               ...     ...        ...
# 2020-07-23   15510481  633506    8710969
# 2020-07-24   15791645  639650    8939705
# 2020-07-25   16047190  644517    9158743
# 2020-07-26   16251796  648621    9293464
# 2020-07-27   16480485  654036    9468087
#
# [188 rows x 3 columns]

# %% [markdown]
# ### 시간에 따른 누적 확진자, 사망자, 회복자 그래프 (seaborn lineplot)

# %%
plt.figure(figsize=(22,10))
plt.xticks(rotation = 45 )
sns.lineplot(data=date_status)

# %% [markdown]
# #전세계 코로나 바이러스 감염 지도 표시 - 전세계 코로나 바이러스 감염 지도 시각화

# %% [markdown]
# ### 국가별 최신 확진자 데이터 조회

# %%
latestDF
# Out:
#       Province/State         Country/Region  ...  Active             WHO Region
# 48807            NaN            Afghanistan  ...    9796  Eastern Mediterranean
# 48808            NaN                Albania  ...    1991                 Europe
# 48809            NaN                Algeria  ...    7973                 Africa
# 48810            NaN                Andorra  ...      52                 Europe
# 48811            NaN                 Angola  ...     667                 Africa
# ...              ...                    ...  ...     ...                    ...
# 49063            NaN  Sao Tome and Principe  ...     117                 Africa
# 49064            NaN                  Yemen  ...     375  Eastern Mediterranean
# 49065            NaN                Comoros  ...      19                 Africa
# 49066            NaN             Tajikistan  ...    1147                 Europe
# 49067            NaN                Lesotho  ...     365                 Africa
#
# [261 rows x 10 columns]

# %%
#확진자수가 많은 국가 10개 까지 조회
latestDF.sort_values(by='Confirmed',ascending=False).head(10)
# Out:
#       Province/State  Country/Region  ...   Active             WHO Region
# 49030            NaN              US  ...  2816444               Americas
# 48835            NaN          Brazil  ...   508116               Americas
# 48936            NaN           India  ...   495499        South-East Asia
# 48992            NaN          Russia  ...   201097                 Europe
# 49005            NaN    South Africa  ...   170537                 Africa
# 48963            NaN          Mexico  ...    47657               Americas
# 48986            NaN            Peru  ...    98752               Americas
# 48854            NaN           Chile  ...    18782               Americas
# 49028            NaN  United Kingdom  ...   254352                 Europe
# 48938            NaN            Iran  ...    22550  Eastern Mediterranean
#
# [10 rows x 10 columns]

# %%
#확진자수가 적은 국가 10개 까지 조회
latestDF.sort_values(by='Confirmed',ascending=False).tail(10)
# Out:
#                     Province/State  Country/Region  ...  Active       WHO Region
# 49059  Falkland Islands (Malvinas)  United Kingdom  ...       0           Europe
# 49027                   Montserrat  United Kingdom  ...       1           Europe
# 48932                          NaN        Holy See  ...       0           Europe
# 49062                          NaN  Western Sahara  ...       1           Africa
# 49053       British Virgin Islands  United Kingdom  ...       0           Europe
# 48918             Saint Barthelemy          France  ...       1           Europe
# 49048        Northwest Territories          Canada  ...       5         Americas
# 49060    Saint Pierre and Miquelon          France  ...       3           Europe
# 49052                     Anguilla  United Kingdom  ...       0           Europe
# 48884                        Tibet           China  ...       0  Western Pacific
#
# [10 rows x 10 columns]

# %%
latestDF_lowconfirm=latestDF.groupby('Country/Region')['Confirmed','Deaths','Recovered','Active'].sum().sort_values(by='Confirmed')
latestDF_lowconfirm
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                        Confirmed  Deaths  Recovered  Active
# Country/Region
# Western Sahara                10       1          8       1
# Holy See                      12       0         12       0
# Greenland                     14       0         13       1
# Saint Kitts and Nevis         17       0         15       2
# Dominica                      18       0         18       0
# Laos                          20       0         19       1
# Grenada                       23       0         23       0
# Timor-Leste                   24       0          0      24
# Saint Lucia                   24       0         22       2
# Fiji                          27       0         18       9

# %% [markdown]
# ### 지도에 전세계 국가별 확진자 수 CircleMarker로 표시

# %%
import folium

# %%
m = folium.Map(location=[0, 0], zoom_start=4)
for n in latestDF.index:
    folium.CircleMarker([latestDF['Lat'][n], latestDF['Long'][n]], radius = int(latestDF['Confirmed'][n]/10000)
    , color='red', fill="True", fill_color='red', popup=latestDF['Country/Region'][n] + ":" + str(latestDF['Confirmed'][n])).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_6bfbf250ba3946e7b21182dec3948cab%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_6bfbf250ba3946e7b21182dec3948cab%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_6bfbf250ba3946e7b21182dec3948cab%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_6bfbf250ba3946e7b21182dec3948cab%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B0%2C%200%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%204%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_bd3790c87a9246c9af904358a9e87a88%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20%20%20%20%20%22detect ...

# %% [markdown]
# ##결론
# 지도화와 차트를 통해 국가별 확진자수를 확인해보았다. 우선 확진자수가 월등히 높은 미국,브라질,인도,러시아,남아공과 같은 나라는 확진자가 월등히 높으므로, 더욱 강력한 입출국 규제가 필요할 것으로 보인다.
#
# 확진자가 낮은 국가를 한번 보면 Western Sahara,Holy See,Greenland,Saint Kitts and Nevis,Dominica 등이 있는 데, 이러한 나라들이 확진자가 적다고 입출국 규제를 완화해도 될까? 안된다. 이 나라들은 인구가 극히 적인 나라들로 인구당 확진자수로 봤을 때 결코 낮은 수치가 아니다. 이러한 국가들에 대한 입출국 규제 역시 간과해서는 안된다.
